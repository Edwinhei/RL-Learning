# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
import matplotlib.pyplot as plt

# 设置随机种子
# torch.manual_seed(42)
# np.random.seed(42)

# 定义Actor-Critic网络（加深网络）
class ActorCritic(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.actor = nn.Linear(hidden_dim, output_dim)
        self.critic = nn.Linear(hidden_dim, 1)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        action_probs = F.softmax(self.actor(x), dim=-1)
        value = self.critic(x)
        return action_probs, value

# 选择动作
def select_action(state, model, device):
    state = torch.FloatTensor(state).to(device)
    action_probs, value = model(state)
    m = Categorical(action_probs)
    action = m.sample()
    log_prob = m.log_prob(action).unsqueeze(0)
    entropy = m.entropy().unsqueeze(0)
    return action.item(), log_prob, value, entropy

# 训练函数
def train(env, model, optimizer, device, num_episodes=5000, gamma=0.99, max_trajectory_length=500, entropy_beta=0.001, n_step=5, critic_weight=2.0):
    episode_rewards = []
    actor_losses = []
    critic_losses = []
    entropies = []
    
    for episode in range(num_episodes):
        # 更快熵衰减
        beta = entropy_beta * (0.001 ** (episode / num_episodes))
        
        state, _ = env.reset()
        log_probs = []
        values = []
        rewards = []
        next_states = []
        dones = []
        episode_entropies = []
        step_count = 0
        
        # 收集轨迹
        while True:
            action, log_prob, value, entropy = select_action(state, model, device)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated or (step_count >= max_trajectory_length - 1)
            
            log_probs.append(log_prob)
            values.append(value)
            rewards.append(reward)
            next_states.append(next_state)
            dones.append(done)
            episode_entropies.append(entropy)
            
            state = next_state
            step_count += 1
            if done:
                break
        
        # 计算 n-step 回报和优势
        values = torch.cat(values)  # [T]
        log_probs = torch.cat(log_probs)  # [T, 1]
        episode_entropies = torch.cat(episode_entropies)  # [T, 1]
        td_targets = []
        
        T = len(rewards)
        for t in range(T):
            n_step_return = torch.tensor(0.0, device=device, dtype=torch.float32)
            max_steps = min(n_step, T - t)
            terminated = False
            
            for i in range(max_steps):
                n_step_return += (gamma ** i) * rewards[t + i]
                if dones[t + i]:
                    terminated = True
                    max_steps = i + 1
                    break
            
            if not terminated and t + n_step < T:
                next_state = torch.FloatTensor(next_states[t + n_step]).to(device)
                with torch.no_grad():
                    _, next_value = model(next_state)
                n_step_return += (gamma ** max_steps) * next_value.squeeze()
            
            td_targets.append(n_step_return.unsqueeze(0))
        
        td_targets = torch.cat(td_targets)  # [T]
        advantage = td_targets - values  # [T, raw values]
        
        # 计算损失
        actor_loss = -(log_probs.squeeze() * advantage.detach()).mean()
        entropy_loss = -episode_entropies.mean()
        actor_loss = actor_loss + beta * entropy_loss
        critic_loss = advantage.pow(2).mean()
        loss = actor_loss + critic_weight * critic_loss
        
        # 记录损失和熵
        actor_losses.append(actor_loss.item())
        critic_losses.append(critic_loss.item())
        entropies.append(episode_entropies.mean().item())
        
        # 更新模型
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
        
        total_reward = sum(rewards)
        episode_rewards.append(total_reward)
        
        if episode % 100 == 0:
            print(f"Episode {episode}, Total Reward: {total_reward:.2f}, Trajectory Length: {len(rewards)}")
            print(f"==> Total Loss: {loss:.4f}, Actor Loss: {actor_loss:.4f}, Critic Loss: {critic_loss:.4f}, Entropy Loss: {entropy_loss:.4f}, Avg Entropy: {entropies[-1]:.4f}, Beta: {beta:.6f}")
            print(f"Advantage Mean: {advantage.mean().item():.4f}, Std: {advantage.std().item():.4f}")
            print(f"TD Targets Mean: {td_targets.mean().item():.4f}, Std: {td_targets.std().item():.4f}")
            print("# ------------------------------------------------- #")
    
    return episode_rewards, actor_losses, critic_losses, entropies

# 测试函数
def test(env, model, device, num_episodes=5, max_trajectory_length=500):
    model.eval()
    test_rewards = []
    for episode in range(num_episodes):
        state, _ = env.reset()
        total_reward = 0
        done = False
        step_count = 0
        
        print(f"Testing Episode {episode + 1}/{num_episodes}")
        while not done:
            action, _, _, _ = select_action(state, model, device)
            state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated or (step_count >= max_trajectory_length - 1)
            total_reward += reward
            step_count += 1
            env.render()
            if done:
                break
        
        test_rewards.append(total_reward)
        print(f"Episode {episode + 1} Reward: {total_reward:.2f}, Length: {step_count}")
    
    avg_reward = np.mean(test_rewards)
    std_reward = np.std(test_rewards)
    return test_rewards, avg_reward, std_reward

# 评估和可视化
def evaluate_and_plot(episode_rewards, actor_losses, critic_losses, entropies, test_rewards, avg_reward, std_reward):
    plt.figure(figsize=(20, 5))
    
    plt.subplot(1, 4, 1)
    plt.plot(episode_rewards, label="Episode Reward", alpha=0.5)
    plt.plot(np.convolve(episode_rewards, np.ones(100)/100, mode='valid'), 
             label="Moving Avg (100)", color='red')
    plt.title("Training Reward Curve")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.legend()
    
    plt.subplot(1, 4, 2)
    plt.plot(actor_losses, label="Actor Loss", alpha=0.5)
    plt.plot(np.convolve(actor_losses, np.ones(100)/100, mode='valid'), 
             label="Moving Avg (100)", color='red')
    plt.title("Actor Loss Curve")
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.subplot(1, 4, 3)
    plt.plot(critic_losses, label="Critic Loss", alpha=0.5)
    plt.plot(np.convolve(critic_losses, np.ones(100)/100, mode='valid'), 
             label="Moving Avg (100)", color='red')
    plt.title("Critic Loss Curve")
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.subplot(1, 4, 4)
    plt.plot(entropies, label="Entropy", alpha=0.5)
    plt.plot(np.convolve(entropies, np.ones(100)/100, mode='valid'), 
             label="Moving Avg (100)", color='red')
    plt.title("Entropy Curve")
    plt.xlabel("Episode")
    plt.ylabel("Entropy")
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('training_plots.png')
    
    plt.figure(figsize=(5, 5))
    plt.hist(test_rewards, bins=20)
    plt.title(f'Test Rewards\nMean: {avg_reward:.2f}, Std: {std_reward:.2f}')
    plt.xlabel("Total Reward")
    plt.ylabel("Frequency")
    plt.savefig('test_rewards_histogram.png')

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    train_env = gym.make("CartPole-v1")
    test_env = gym.make('CartPole-v1', render_mode='human')
    
    input_dim = train_env.observation_space.shape[0]
    hidden_dim = 128
    output_dim = train_env.action_space.n

    model = ActorCritic(input_dim, hidden_dim, output_dim).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.002)
    
    print("Training...")
    episode_rewards, actor_losses, critic_losses, entropies = train(train_env, model, optimizer, device, num_episodes=2000, n_step=5)
    
    print("\nTesting with visualization...")
    test_rewards, avg_reward, std_reward = test(test_env, model, device)
    print(f"Average Test Reward: {avg_reward:.2f} ± {std_reward:.2f}")
    
    print("\nPlotting results...")
    evaluate_and_plot(episode_rewards, actor_losses, critic_losses, entropies, test_rewards, avg_reward, std_reward)
    
    train_env.close()
    test_env.close()

if __name__ == "__main__":
    main()
# Out:
# Training...
# Episode 0, Total Reward: 15.00, Trajectory Length: 15
# ==> Total Loss: 42.7926, Actor Loss: 3.0702, Critic Loss: 19.8612, Entropy Loss: -0.6905, Avg Entropy: 0.6905, Beta: 0.001000
# Advantage Mean: 4.3167, Std: 1.1465
# TD Targets Mean: 4.0897, Std: 1.1676
# # ------------------------------------------------- #
# Episode 100, Total Reward: 21.00, Trajectory Length: 21
# ==> Total Loss: 22.6316, Actor Loss: 1.3935, Critic Loss: 10.6190, Entropy Loss: -0.6415, Avg Entropy: 0.6415, Beta: 0.000708
# Advantage Mean: 1.8543, Std: 2.7458
# TD Targets Mean: 9.2659, Std: 3.9184
# # ------------------------------------------------- #
# Episode 200, Total Reward: 20.00, Trajectory Length: 20
# ==> Total Loss: 73.6823, Actor Loss: -0.0798, Critic Loss: 36.8811, Entropy Loss: -0.6707, Avg Entropy: 0.6707, Beta: 0.000501
# Advantage Mean: 0.0157, Std: 6.2307
# TD Targets Mean: 12.7091, Std: 6.0635
# # ------------------------------------------------- #
# Episode 300, Total Reward: 44.00, Trajectory Length: 44
# ==> Total Loss: 54.1488, Actor Loss: 0.8958, Critic Loss: 26.6265, Entropy Loss: -0.6671, Avg Entropy: 0.6671, Beta: 0.000355
# Advantage Mean: 1.4311, Std: 5.0150
# TD Targets Mean: 19.4914, Std: 6.8520
# # ------------------------------------------------- #
# Episode 400, Total Reward: 202.00, Trajectory Length: 202
# ==> Total Loss: 72.9301, Actor Loss: 1.2093, Critic Loss: 35.8604, Entropy Loss: -0.6372, Avg Entropy: 0.6372, Beta: 0.000251
# Advantage Mean: 2.4284, Std: 5.4875
# TD Targets Mean: 34.3563, Std: 5.9624
# # ------------------------------------------------- #
# Episode 500, Total Reward: 126.00, Trajectory Length: 126
# ==> Total Loss: 50.7954, Actor Loss: 0.6932, Critic Loss: 25.0511, Entropy Loss: -0.5887, Avg Entropy: 0.5887, Beta: 0.000178
# Advantage Mean: 1.3644, Std: 4.8348
# TD Targets Mean: 31.0820, Std: 10.9390
# # ------------------------------------------------- #
# Episode 600, Total Reward: 215.00, Trajectory Length: 215
# ==> Total Loss: 19.3853, Actor Loss: 0.1649, Critic Loss: 9.6102, Entropy Loss: -0.6017, Avg Entropy: 0.6017, Beta: 0.000126
# Advantage Mean: 0.7072, Std: 3.0253
# TD Targets Mean: 49.5565, Std: 19.9357
# # ------------------------------------------------- #
# Episode 700, Total Reward: 402.00, Trajectory Length: 402
# ==> Total Loss: 21.4422, Actor Loss: 0.2209, Critic Loss: 10.6107, Entropy Loss: -0.5913, Avg Entropy: 0.5913, Beta: 0.000089
# Advantage Mean: 0.6829, Std: 3.1890
# TD Targets Mean: 64.0998, Std: 19.8570
# # ------------------------------------------------- #
# Episode 800, Total Reward: 441.00, Trajectory Length: 441
# ==> Total Loss: 24.2048, Actor Loss: 0.1208, Critic Loss: 12.0420, Entropy Loss: -0.5782, Avg Entropy: 0.5782, Beta: 0.000063
# Advantage Mean: 0.5241, Std: 3.4342
# TD Targets Mean: 66.9824, Std: 20.8463
# # ------------------------------------------------- #
# Episode 900, Total Reward: 277.00, Trajectory Length: 277
# ==> Total Loss: 90.1326, Actor Loss: 0.2029, Critic Loss: 44.9649, Entropy Loss: -0.5476, Avg Entropy: 0.5476, Beta: 0.000045
# Advantage Mean: -0.3988, Std: 6.7058
# TD Targets Mean: 73.7486, Std: 15.6818
# # ------------------------------------------------- #
# Episode 1000, Total Reward: 500.00, Trajectory Length: 500
# ==> Total Loss: 148.4523, Actor Loss: -0.2267, Critic Loss: 74.3395, Entropy Loss: -0.5790, Avg Entropy: 0.5790, Beta: 0.000032
# Advantage Mean: 0.2036, Std: 8.6283
# TD Targets Mean: 79.6777, Std: 8.1927
# # ------------------------------------------------- #
# Episode 1100, Total Reward: 500.00, Trajectory Length: 500
# ==> Total Loss: 45.4797, Actor Loss: -0.1018, Critic Loss: 22.7908, Entropy Loss: -0.5602, Avg Entropy: 0.5602, Beta: 0.000022
# Advantage Mean: 0.0269, Std: 4.7787
# TD Targets Mean: 79.5402, Std: 13.1642
# # ------------------------------------------------- #
# Episode 1200, Total Reward: 309.00, Trajectory Length: 309
# ==> Total Loss: 10.1315, Actor Loss: 0.3259, Critic Loss: 4.9028, Entropy Loss: -0.5207, Avg Entropy: 0.5207, Beta: 0.000016
# Advantage Mean: 0.8291, Std: 2.0565
# TD Targets Mean: 49.7283, Std: 23.5713
# # ------------------------------------------------- #
# Episode 1300, Total Reward: 500.00, Trajectory Length: 500
# ==> Total Loss: 142.7673, Actor Loss: -0.3551, Critic Loss: 71.5612, Entropy Loss: -0.5610, Avg Entropy: 0.5610, Beta: 0.000011
# Advantage Mean: -0.4038, Std: 8.4582
# TD Targets Mean: 90.1612, Std: 9.1279
# # ------------------------------------------------- #
# Episode 1400, Total Reward: 500.00, Trajectory Length: 500
# ==> Total Loss: 74.0916, Actor Loss: 1.0682, Critic Loss: 36.5117, Entropy Loss: -0.5092, Avg Entropy: 0.5092, Beta: 0.000008
# Advantage Mean: 2.3445, Std: 5.5747
# TD Targets Mean: 44.3447, Std: 7.5049
# # ------------------------------------------------- #
# Episode 1500, Total Reward: 500.00, Trajectory Length: 500
# ==> Total Loss: 111.9001, Actor Loss: -0.0187, Critic Loss: 55.9594, Entropy Loss: -0.5284, Avg Entropy: 0.5284, Beta: 0.000006
# Advantage Mean: -0.0380, Std: 7.4880
# TD Targets Mean: 82.8485, Std: 9.2676
# # ------------------------------------------------- #
# Episode 1600, Total Reward: 24.00, Trajectory Length: 24
# ==> Total Loss: 3287.7490, Actor Loss: -12.7057, Critic Loss: 1650.2274, Entropy Loss: -0.3652, Avg Entropy: 0.3652, Beta: 0.000004
# Advantage Mean: -18.9876, Std: 36.6848
# TD Targets Mean: 71.8478, Std: 36.2462
# # ------------------------------------------------- #
# Episode 1700, Total Reward: 16.00, Trajectory Length: 16
# ==> Total Loss: 3793.4272, Actor Loss: -9.1952, Critic Loss: 1901.3113, Entropy Loss: -0.3429, Avg Entropy: 0.3429, Beta: 0.000003
# Advantage Mean: -25.0759, Std: 36.8422
# TD Targets Mean: 58.5493, Std: 38.8691
# # ------------------------------------------------- #
# Episode 1800, Total Reward: 500.00, Trajectory Length: 500
# ==> Total Loss: 112.6747, Actor Loss: -0.2933, Critic Loss: 56.4840, Entropy Loss: -0.5555, Avg Entropy: 0.5555, Beta: 0.000002
# Advantage Mean: -0.6396, Std: 7.4958
# TD Targets Mean: 92.3719, Std: 10.4271
# # ------------------------------------------------- #
# Episode 1900, Total Reward: 500.00, Trajectory Length: 500
# ==> Total Loss: 57.2658, Actor Loss: 0.2550, Critic Loss: 28.5054, Entropy Loss: -0.4934, Avg Entropy: 0.4934, Beta: 0.000001
# Advantage Mean: 0.4525, Std: 5.3252
# TD Targets Mean: 73.3008, Std: 10.7265
# # ------------------------------------------------- #
#
# Testing with visualization...
# Testing Episode 1/5
# Episode 1 Reward: 500.00, Length: 500
# Testing Episode 2/5
# Episode 2 Reward: 500.00, Length: 500
# Testing Episode 3/5
# Episode 3 Reward: 500.00, Length: 500
# Testing Episode 4/5
# Episode 4 Reward: 500.00, Length: 500
# Testing Episode 5/5
# Episode 5 Reward: 500.00, Length: 500
# Average Test Reward: 500.00 ± 0.00
#
# Plotting results...
